# %%
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
import tensorflow as tf 
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
mnist = keras.datasets.mnist
mnist
# Out:
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# <module 'keras.api._v2.keras.datasets.mnist' from 'c:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\keras\\api\\_v2\\keras\\datasets\\mnist\\__init__.py'>

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
fig, axs = plt.subplots(4,5, figsize=(12,6)) #4 é o número de linhas e 5 o número de colunas

for i, ax in enumerate(axs.flat):
    ax.imshow(x_train[i], cmap='gray')
    ax.set_title(f"Número: {y_train[i]}")
    ax.axis("off")

fig.subplots_adjust(hspace=0.60)    
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 12))

ax.imshow(x_train[0], cmap="gray")

for linha in range(28):
    for coluna in range(28):
        valor_cor = x_train[0][linha][coluna]
        ax.annotate(
            str(valor_cor),
            xy=(coluna,linha),
            color = "black" if valor_cor > 100 else "white",
            horizontalalignment = "center",
            verticalalignment = "center"
        )

plt.show()

# %%
fig, ax = plt.subplots(figsize=(13, 13))

ax.imshow(x_train[0]/255, cmap="gray")

for linha in range(28):
    for coluna in range(28):
        valor_cor = x_train[0][linha][coluna]/255
        ax.annotate(
            f"{valor_cor:.2f}",
            xy=(coluna,linha),
            color = "black" if valor_cor > 0.5 else "white",
            horizontalalignment = "center",
            verticalalignment = "center"
        )

plt.show()

# %% [markdown]
# Criação do modelo

# %%
def model_builder(hp):
    model = keras.models.Sequential()
    
    model.add(keras.layers.InputLayer(input_shape=(28, 28, 1)))
    model.add(keras.layers.Rescaling(scale=1./255))
    
    model.add(keras.layers.RandomRotation(0.1))
    model.add(keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1))
    model.add(keras.layers.RandomZoom(0.1))
    
    model.add(keras.layers.Conv2D(
        hp.Int("conv_1_filters",  min_value=16, max_value=64, step=2, sampling="log"), 
        (3, 3),  
        activation="relu"))
    model.add(keras.layers.MaxPooling2D())
    model.add(keras.layers.Dropout(0.2))
    
    model.add(keras.layers.Conv2D(
        hp.Int("conv_2_filters",  min_value=32, max_value=128, step=2, sampling="log"), 
        (3, 3),  
        activation="relu"))
    model.add(keras.layers.MaxPooling2D())
    model.add(keras.layers.Dropout(0.2))
    
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(10, activation="softmax"))


    optimizer = keras.optimizers.Adam(learning_rate=hp.Choice("learning_rate", values=[1E-2, 1E-3, 1E-4]))
    loss = keras.losses.SparseCategoricalCrossentropy()
    metric = keras.metrics.SparseCategoricalAccuracy()
    
    model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

    return model

# %% [markdown]
# Compilar o modelo Keras

# %%
import keras_tuner as kt

tuner = kt.Hyperband(
    model_builder,
    objective="val_loss",
    max_epochs=10,
    factor=3,
    directory="tuner",
    project_name="mnist",
)
# Out:
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# Fit do modelo

# %%
early_stop = keras.callbacks.EarlyStopping(
    patience=5,
    verbose=1,
    min_delta=1E-4,
)

tuner.search(
    x_train,
    y_train,
    epochs=300,
    batch_size=512,
    validation_split=0.2,
    callbacks= [early_stop],
)
# Out:
# Trial 30 Complete [00h 02m 33s]
# val_loss: 0.06119342893362045
#
# Best val_loss So Far: 0.05503832921385765
# Total elapsed time: 00h 35m 46s

# %%
best_hps = tuner.get_best_hyperparameters()[0]

# %%
best_hps.values
# Out:
# {'conv_1_filters': 16,
#  'conv_2_filters': 128,
#  'learning_rate': 0.01,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 4,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0012'}

# %%
model = tuner.hypermodel.build(best_hps)

history = model.fit(
    x_train,
    y_train,
    epochs=300,
    batch_size=256,
    validation_split=0.2,
    callbacks= [early_stop],
)
# Out:
# Epoch 1/300
# 188/188 [==============================] - 19s 90ms/step - loss: 0.5809 - sparse_categorical_accuracy: 0.8126 - val_loss: 0.1215 - val_sparse_categorical_accuracy: 0.9645
# Epoch 2/300
# 188/188 [==============================] - 17s 91ms/step - loss: 0.2552 - sparse_categorical_accuracy: 0.9201 - val_loss: 0.0788 - val_sparse_categorical_accuracy: 0.9762
# Epoch 3/300
# 188/188 [==============================] - 16s 84ms/step - loss: 0.2136 - sparse_categorical_accuracy: 0.9338 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9800
# Epoch 4/300
# 188/188 [==============================] - 13s 71ms/step - loss: 0.1783 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9806
# Epoch 5/300
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1700 - sparse_categorical_accuracy: 0.9463 - val_loss: 0.0546 - val_sparse_categorical_accuracy: 0.9843
# Epoch 6/300
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1596 - sparse_categorical_accuracy: 0.9506 - val_loss: 0.0707 - val_sparse_categorical_accuracy: 0.9802
# Epoch 7/300
# 188/188 [==============================] - 13s 70ms/step - loss: 0.1501 - sparse_categorical_accuracy: 0.9539 - val_loss: 0.0608 - val_sparse_categorical_accuracy: 0.9835
# Epoch 8/300
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1445 - sparse_categorical_accuracy: 0.9552 - val_loss: 0.0782 - val_sparse_categorical_accuracy: 0.9785
# Epoch 9/300
# 188/188 [==============================] - 13s 70ms/step - loss: 0.1505 - sparse_categorical_accuracy: 0.9536 - val_loss: 0.0601 - val_sparse_categorical_accuracy: 0.9841
# Epoch 10/300
# 188/188 [==============================] - 14s 73ms/step - loss: 0.1446 - sparse_categorical_accuracy: 0.9551 - val_loss: 0.0617 - val_sparse_categorical_accuracy: 0.9827
# Epoch 10: early stopping

# %% [markdown]
# Evaluate do modelo

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0574 - sparse_categorical_accuracy: 0.9836
# [0.0573577806353569, 0.9836000204086304]

# %% [markdown]
# Predict do modelo

# %%
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.legend()
plt.show()

# %%
plt.plot(history.history["sparse_categorical_accuracy"], label="sparse_categorical_accuracy")
plt.plot(history.history["val_sparse_categorical_accuracy"], label="val_sparse_categorical_accuracy")
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(4,5, figsize=(17,6)) #4 é o número de linhas e 5 o número de colunas

for i, ax in enumerate(axs.flat):
    ax.imshow(x_test[i], cmap='gray')
    pred = model.predict(np.expand_dims(x_test[i], axis=0), verbose=0)[0]
    ax.set_title(f"verdade: {y_test[i]}", pad=15) #pad é para espaçar
    ax.axis("off")
    ax.text(
        0,
        -2,
        f"predição: {pred.argmax()}-{pred.max():.1%}",
        color="green" if pred.argmax() == y_test[i] else "red"
    )
fig.subplots_adjust(hspace=0.60) 
plt.show()

# %%
from pathlib import Path

test_images_dir = Path(r"C:\Users\User\Desktop\CienciadeDados\CursoHashtag\Deeplearning\test_images")

fig, axs = plt.subplots(2, 5, figsize=(10,5))

all_pred = {}

for i, (img, ax) in enumerate(zip(sorted(test_images_dir.glob("*.png")), axs.flat)):
    name = img.name.split(".")[0] #O [0] é por conta do batch que veio a partir do expand.dims
    #
    img = keras.preprocessing.image.load_img(
        img, target_size=(28,28), color_mode="grayscale"
    )
    #
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = 255 - img_array
    img_array = tf.expand_dims(img_array, 0)
    
    pred = model.predict(img_array, verbose=0)
    all_pred[name] = pred
    
    ax.imshow(img_array[0], cmap='gray')
    ax.set_title(f"verdade: {name}", pad=15) #pad é para espaçar
    ax.axis("off")
    ax.text(
        0,
        -2,
        f"predição: {pred.argmax()}-{pred.max():.1%}",
        color="green" if str(pred.argmax()) == name else "red"
    )
fig.subplots_adjust(hspace=0.60) 
plt.show()

# %%
x = all_pred["7"]
x
# Out:
# array([[1.7924165e-09, 9.2522959e-07, 2.0407063e-03, 6.6626402e-05,
#         6.5893211e-13, 2.7732197e-11, 1.0477914e-12, 9.9789149e-01,
#         2.0602531e-07, 2.9785821e-10]], dtype=float32)

# %% [markdown]
# Salvando o modelo

# %%
model.save(r"C:\Users\User\Desktop\CienciadeDados\CursoHashtag\Deeplearning\modelosalvo\modelo_tuner.keras")

# %%
modelo_salvo = keras.models.load_model(r"C:\Users\User\Desktop\CienciadeDados\CursoHashtag\Deeplearning\modelosalvo\modelo_tuner.keras")

# %%
modelo_salvo.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 28, 28, 1)         0
#
#  random_rotation_2 (RandomR  (None, 28, 28, 1)         0
#  otation)
#
#  random_translation_2 (Rand  (None, 28, 28, 1)         0
#  omTranslation)
#
#  random_zoom_2 (RandomZoom)  (None, 28, 28, 1)         0
#
#  conv2d_4 (Conv2D)           (None, 26, 26, 16)        160
#
#  max_pooling2d_4 (MaxPoolin  (None, 13, 13, 16)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 13, 13, 16)        0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 128)       18560
#
#  max_pooling2d_5 (MaxPoolin  (None, 5, 5, 128)         0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 5, 5, 128)         0
#
#  flatten_2 (Flatten)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 10)                32010
#
# =================================================================
# Total params: 50730 (198.16 KB)
# Trainable params: 50730 (198.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
modelo_salvo.evaluate(x_train,y_train)
# Out:
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0553 - sparse_categorical_accuracy: 0.9843
# [0.05527879670262337, 0.9842666387557983]
